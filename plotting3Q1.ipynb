# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuvan0808/Machine_learning/blob/main/plotting3Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Lab3.csv")

# %%
df.head()
# Out:
#     Sn Department     Name of student Program  \
# 0  1.0         BT              Ayushi  B.Tech
# 1  2.0         BT        Bharti Singh  B.Tech
# 2  3.0         BT       Muskan Bhatia  B.Tech
# 3  4.0         BT  Divyansh Choudhary  B.Tech
# 4  5.0         BT        Khushi Singh  B.Tech
#
#    Paypackage at appointment in LPA PlacedBy
# 0                              4.50        D
# 1                              3.00        D
# 2                              3.00        D
# 3                              2.16        S
# 4                              4.50        S

# %%
df.isnull()
# Out:
#         Sn  Department  Name of student  Program  \
# 0    False       False            False    False
# 1    False       False            False    False
# 2    False       False            False    False
# 3    False       False            False    False
# 4    False       False            False    False
# ..     ...         ...              ...      ...
# 984   True        True             True     True
# 985   True        True             True     True
# 986   True        True             True     True
# 987   True        True             True     True
# 988   True        True             True     True
#
#      Paypackage at appointment in LPA  PlacedBy
# 0                               False     False
# 1                               False     False
# 2                               False     False
# 3                               False     False
# 4                               False     False
# ..                                ...       ...
# ...

# %%
type(df.isnull())
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum()
# Out:
# Sn                                  819
# Department                          819
# Name of student                     819
# Program                             819
# Paypackage at appointment in LPA    819
# PlacedBy                            819
# dtype: int64

# %%
df.isnull().any().any().any()
# Out:
# True

# %%
df.isnull()
# Out:
#         Sn  Department  Name of student  Program  \
# 0    False       False            False    False
# 1    False       False            False    False
# 2    False       False            False    False
# 3    False       False            False    False
# 4    False       False            False    False
# ..     ...         ...              ...      ...
# 984   True        True             True     True
# 985   True        True             True     True
# 986   True        True             True     True
# 987   True        True             True     True
# 988   True        True             True     True
#
#      Paypackage at appointment in LPA  PlacedBy
# 0                               False     False
# 1                               False     False
# 2                               False     False
# 3                               False     False
# 4                               False     False
# ..                                ...       ...
# ...

# %%
type(df.isnull().any().any().any())
# Out:
# numpy.bool_

# %%
df.fillna(0)
# Out:
#       Sn Department     Name of student Program  \
# 0    1.0         BT              Ayushi  B.Tech
# 1    2.0         BT        Bharti Singh  B.Tech
# 2    3.0         BT       Muskan Bhatia  B.Tech
# 3    4.0         BT  Divyansh Choudhary  B.Tech
# 4    5.0         BT        Khushi Singh  B.Tech
# ..   ...        ...                 ...     ...
# 984  0.0          0                   0       0
# 985  0.0          0                   0       0
# 986  0.0          0                   0       0
# 987  0.0          0                   0       0
# 988  0.0          0                   0       0
#
#      Paypackage at appointment in LPA PlacedBy
# 0                                4.50        D
# 1                                3.00        D
# 2                                3.00        D
# 3                                2.16        S
# 4                                4.50        S
# ..                                ...      ...
# 984                              0.00        0
# ...

# %%
df.describe()
# Out:
#                Sn  Paypackage at appointment in LPA
# count  170.000000                        170.000000
# mean    85.500000                          4.937765
# std     49.218899                          1.545581
# min      1.000000                          2.160000
# 25%     43.250000                          4.000000
# 50%     85.500000                          4.500000
# 75%    127.750000                          5.000000
# max    170.000000                         12.500000

# %%
f,ax = plt.subplots(figsize=(18,18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.2f',ax=ax,cmap="YlGnBu")
plt.show()

# %%
plt.title("Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.xlabel('Paypackage at appointment in LPA')
plt.ylabel('PlacedBy')
# Out:
# Text(0, 0.5, 'PlacedBy')

# %%
sns.barplot(x='Name of student',y='Paypackage at appointment in LPA',data=df)

# %%
sns.countplot(x='Name of student',data=df)

# %%
df['Name of student'].value_counts()

# %%
sns.boxplot(x='Name of student',y='Paypackage at appointment in LPA',data=df)

# %%
sns.countplot(x='Name of student',data=df,hue='Program')
